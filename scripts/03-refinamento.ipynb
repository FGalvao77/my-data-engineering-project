# %%
import duckdb

# %%
con = duckdb.connect(
    database='./data_duckdb.db',
    read_only=False
)

# %%
con.execute(
    '''
    SELECT *
    FROM products
    '''
).fetchdf()
# Out:
#       id product_name id_category  id_supplier  value_price
# 0  10002      MARTELO        BT50          100       1500.0
# 1  10003        PREGO        BT10          100         60.0
# 2  10005      MACHADO        BT50          100        100.0
# 3  10001     PARAFUSO        BT10          100        100.0
# 4  10004        SERRA        BT50          100        200.0

# %%
df = con.execute(
    '''
    SELECT *
    FROM products
    '''
).fetchdf()

df
# Out:
#       id product_name id_category  id_supplier  value_price
# 0  10002      MARTELO        BT50          100       1500.0
# 1  10003        PREGO        BT10          100         60.0
# 2  10005      MACHADO        BT50          100        100.0
# 3  10001     PARAFUSO        BT10          100        100.0
# 4  10004        SERRA        BT50          100        200.0

# %%
df2 = df.drop(columns=['id_category', 'id_supplier'])

# %%
df2
# Out:
#       id product_name  value_price
# 0  10002      MARTELO       1500.0
# 1  10003        PREGO         60.0
# 2  10005      MACHADO        100.0
# 3  10001     PARAFUSO        100.0
# 4  10004        SERRA        200.0

# %%
con.execute(
    '''
    CREATE TABLE IF NOT EXISTS dim_products (
        product_id BIGINT,
        product_name TEXT,
        product_value FLOAT
    )
    '''
)

# %%
df_dim = con.execute(
    '''
    SELECT *
    FROM dim_products
    '''
).fetchdf()

df_dim
# Out:
#    PRODUCT_ID PRODUCT_NAME  PRODUCUT_VALUE
# 0       10002      MARTELO          1500.0
# 1       10003        PREGO            60.0
# 2       10005      MACHADO           100.0
# 3       10001     PARAFUSO           100.0
# 4       10004        SERRA           200.0
# 5       10002      MARTELO          1500.0
# 6       10003        PREGO            60.0
# 7       10005      MACHADO           100.0
# 8       10001     PARAFUSO           100.0
# 9       10004        SERRA           200.0

# %%
con.execute(
    '''
    DROP TABLE dim_products
    '''
)

# %%
con.execute(
    '''
    SELECT *
    FROM dim_products
    '''
).fetchdf()
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 con.execute(
#       2     '''
#       3     SELECT *
#       4     FROM dim_products
#       5     '''
#       6 ).fetchdf()
#
# CatalogException: Catalog Error: Table with name dim_products does not exist!
# Did you mean "products"?
#
# LINE 3:     FROM dim_products
#                  ^

# %%
con.execute(
    '''
    CREATE TABLE IF NOT EXISTS dim_products (
        PRODUCT_ID BIGINT,
        PRODUCT_NAME TEXT,
        PRODUCT_VALUE FLOAT
    )
    '''
)

# %%
con.execute(
    '''
    SELECT *
    FROM dim_products
    '''
).fetchdf()
# Out:
# Empty DataFrame
# Columns: [PRODUCT_ID, PRODUCT_NAME, PRODUCT_VALUE]
# Index: []

# %%
df2
# Out:
#       id product_name  value_price
# 0  10002      MARTELO       1500.0
# 1  10003        PREGO         60.0
# 2  10005      MACHADO        100.0
# 3  10001     PARAFUSO        100.0
# 4  10004        SERRA        200.0

# %%
con.execute(
    '''
    INSERT INTO dim_products
    SELECT *
    FROM df2
    '''
)

# %%
df_dim = con.execute(
    '''
    SELECT *
    FROM dim_products
    '''
).fetchdf()

df_dim
# Out:
#    PRODUCT_ID PRODUCT_NAME  PRODUCT_VALUE
# 0       10002      MARTELO         1500.0
# 1       10003        PREGO           60.0
# 2       10005      MACHADO          100.0
# 3       10001     PARAFUSO          100.0
# 4       10004        SERRA          200.0

# %%
con.close()
